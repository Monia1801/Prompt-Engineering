# %% [markdown]
# <a href="https://colab.research.google.com/github/Monia1801/Prompt-Engineering/blob/main/Exp%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain langchain-google-genai langchain-groq \ langchain-openai langchain-huggingface langchain-openrouter
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.4/120.4 kB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.6/792.6 kB 29.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 463.6/463.6 kB 36.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 54.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.46.4
#     Uninstalling pydantic_core-2.46.4:
#       Successfully uninstalled pydantic_core-2.46.4
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.13.4
#     Uninstalling pydantic-2.13.4:
#       Successfully uninstalled pydantic-2.13.4
# ...

# %%
import os
from google.colab import userdata
from langchain_core.messages import HumanMessage
from langchain.chat_models import init_chat_model
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_groq import ChatGroq

# %%
os.environ.update({
    "GOOGLE_API_KEY":userdata.get('GOOGLE_API_KEY'),
    "GROQ_API_KEY":userdata.get('GROQ_API_KEY'),
    "OPENROUTER_API_KEY": userdata.get('OPENROUTER_API_KEY'),
    "HF_TOKEN": userdata.get('HF_TOKEN')
})

# %%
models = {
     # Explicit initialization via provider-specific classes
     "Google": ChatGoogleGenerativeAI(
         model="gemini-3.1-flash-lite",
         temperature=1.0
      ),
     "Groq": ChatGroq(
         model_name="openai/gpt-oss-120b",
         temperature=1.0
     ),
      "OpenRouter": init_chat_model(
          "nvidia/nemotron-3-super-120b-a12b:free",
          model_provider="openrouter",
          temperature=1.0
        ),
     "HuggingFace": init_chat_model(
         "microsoft/Phi-3-mini-4k-instruct",
         model_provider="huggingface",
         temperature=1.0
         )
     }
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/3.44k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/306 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/599 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/16.5k [00:00<?, ?B/s]
# ...
# Loading weights:   0%|          | 0/195 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# ...

# %%
msg = input("\nEnter your prompt: ")
for llm_name, llm in models.items():
  print(f"\n--- {llm_name} ---")
  response = llm.invoke(msg)
  print(f"{response}")
# Out:
# Enter your prompt: what is prompt engineering
#
# --- Google ---
# ...
